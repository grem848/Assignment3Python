# %% [markdown]
# # Group Good Awareness
#
# Function assignments are in module.py and are imported

# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
import module

filename = './befkbhalderstatkode.csv'
bef_stat = module.get_data(filename)

# calling the function with year = 2015
year = 2015
english, non_english = module.number_of_nonenglish_vs_english(year, bef_stat)
print('Amount of people from native English speaking countries in', year, ':', english)
print('Amount of people from not native English speaking countries in', year, ':', non_english)


swedish_mask = bef_stat[:,3] == 5120
data_filtered = module.mask_function(bef_stat, swedish_mask)
print('Only with Swedish people:\n', data_filtered)

year_mask = bef_stat[:,0] == year
data_year_filtered = module.mask_function(bef_stat, year_mask)
print('Filtered by year:\n', data_year_filtered)
# Out:
# Amount of people from native English speaking countries in 2015 : 9039
# Amount of people from not native English speaking countries in 2015 : 78642
# Only with Swedish people:
#  [[2015    1    0 5120    4]
#  [2015    1    1 5120    4]
#  [2015    1    2 5120    3]
#  ...
#  [1992   99   53 5120    1]
#  [1992   99   54 5120    1]
#  [1992   99   55 5120    1]]
# Filtered by year:
#  [[2015    1    0 5100  614]
#  [2015    1    0 5104    2]
#  [2015    1    0 5106    1]
#  ...
#  [2015   99   82 5100    1]
#  [2015   99   86 5289    1]
#  [2015   99   90 5289    1]]

# %%
# 6. Create Illustration 1: In your notebook use the above function and create a 2d array of year as x and accumulated amount as y:
# create a line graph of the population change over time for all of Copenhagen

mydict = module.get_dict_of_x_values_and_corresponding_sums(bef_stat, 'year')
# prints the line graph
title = 'Amount of Copenhagen citizens over time'
plt.title(title, fontsize=12)
plt.plot(mydict.keys(), mydict.values())
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.close()
# 7: Create illustration 2: In your notebook use your module to create a dataset where development of all German citizens can be shown over time

# first creating the dataset with only Germans included
german_mask = bef_stat[:,3] == 5180
german_data = module.mask_function(bef_stat, german_mask)

# then running it through dict function and printing the graph
german_dict = module.get_dict_of_x_values_and_corresponding_sums(german_data, 'year')
title = 'German citizens over time'
plt.title(title, fontsize=12)
plt.plot(german_dict.keys(), german_dict.values())
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Create illustration 3: Show a bar plot of all the 18-25 year old in the different areas of copenhagen and in the same plot 
# show (in a different color) all 60-67 year old in the different areas.
plt.close()

young_people = module.get_age_group_per_year(bef_stat, 18, 25, 2015)

old_people = module.get_age_group_per_year(bef_stat, 60, 67, 2015)

young_dict = module.get_dict_of_x_values_and_corresponding_sums(young_people, 'area')
old_dict = module.get_dict_of_x_values_and_corresponding_sums(old_people, 'area')

young_values = list(young_dict.values())
old_values = list(old_dict.values())

area_codes = np.unique(bef_stat[:,1])
index = np.arange(1, len(area_codes)+1)
plt.bar(index, young_values, width=0.5, linewidth=0, align='center')
title = '18-25 yearolds vs. 60-67 yearolds over neighbourhoods'
plt.title(title, fontsize=12)
plt.xlabel("Neighbourhoodcode", fontsize=10)
plt.ylabel("Amount", fontsize=10)
plt.xticks(index, area_codes, fontsize=10)
plt.bar(index, old_values, width=0.5, linewidth=0, align='center',color='green', bottom=young_values)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# Create illustration 4: show a pie chart of age groups (0-10, 10-20, 20-30 ...) in Østerbro part
#  of Copenhagen. create another similar piechart for Vesterbro.
plt.close()

# østerbro = 2
year = 2015
list_of_age_group_sums = module.get_list_of_age_group_sums(2, year, bef_stat)

age_groups = ['0-10', '11-21', '21-30', '31-40', '41-50', '51-60', '61-70', '71-80', '81-90', 'Above 90']

labels = age_groups
sizes = list_of_age_group_sums
fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')
title = 'Age distribution Østerbro ' + str(year)
plt.title(title, fontsize=12)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.close()

# vesterbro = 4
list_of_age_group_sums = module.get_list_of_age_group_sums(4, year, bef_stat)

age_groups = ['0-10', '11-21', '21-30', '31-40', '41-50', '51-60', '61-70', '71-80', '81-90', 'Above 90']

labels = age_groups
sizes = list_of_age_group_sums
fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')
title = 'Age distribution Vesterbro ' + str(year)
plt.title(title, fontsize=12)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
